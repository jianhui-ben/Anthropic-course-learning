# %% [markdown]
# # Getting Started with Claude API
#
# This notebook covers the basics of connecting to and using the Claude API.

# %%
# Import our helper functions
import sys
sys.path.append('../')

from utils.claude_helpers import get_claude_client, simple_chat, print_response

# %%
# Test basic connection
try:
    client = get_claude_client()
    print("✅ Successfully connected to Claude API!")
except Exception as e:
    print(f"❌ Error connecting: {e}")
    print("Make sure you've set your ANTHROPIC_API_KEY in .env file")
# Out:
# ✅ Successfully connected to Claude API!

# %%
# Simple chat example
response = simple_chat("Hello! Can you explain what you are in one sentence?")
print_response(response)
# Out:
# ...
# Claude's Response:
# ...
# I am an artificial intelligence created by Anthropic to assist and converse with humans on a wide range of topics.
# ...

# %% [markdown]
# ## Experiment Area
#
# Use the cells below to experiment with different prompts and API calls:

# %%
# Your experiments here
